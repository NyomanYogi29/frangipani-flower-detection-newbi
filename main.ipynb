# %%
from ultralytics import YOLO

# %%
model = YOLO('runs/detect/yolov8n_bunga-kamboja/weights/best.pt')

results = model.train(
    data='bunga-kamboja.yaml',
    epochs=100,
    imgsz=640,
    batch=16,
    name='yolov8n_bunga-kamboja',
    patience=20,
    augment=True
)

print("Training selesai!")
# Out:
# Ultralytics 8.4.41  Python-3.11.1 torch-2.11.0+cpu CPU (AMD Ryzen AI 7 350 w/ Radeon 860M)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=True, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=bunga-kamboja.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=runs/detect/yolov8n_bunga-kamboja/weights/best.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolov8n_bunga-kamboja-2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\runs\detect\yolov8n_bunga-kamboja-2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,238 parameters, 3,011,222 gradients, 8.2 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.10.1 ms, read: 1230.2237.2 MB/s, size: 2139.6 KB)
# train: Scanning C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\labels\train... 190 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 190/190 396.8it/s 0.5s0.1s
# train: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\train\004683f1-1776914759186.jpg: corrupt JPEG restored and saved
# train: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\train\02b5541a-1776914759429.jpg: corrupt JPEG restored and saved
# train: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\train\0367e27d-1776914759339.jpg: corrupt JPEG restored and saved
# train: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\train\0597e0df-1776914759670.jpg: corrupt JPEG restored and saved
# train: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\train\347aef1c-1776914759492.jpg: corrupt JPEG restored and saved
# train: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\train\3fb5b129-1776914759644.jpg: corrupt JPEG restored and saved
# train: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\train\49c6cbbc-1776914759743.jpg: corrupt JPEG restored and saved
# train: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\train\4ca77dde-1776914759726.jpg: corrupt JPEG restored and saved
# train: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\train\52a315ec-1776914759167.jpg: corrupt JPEG restored and saved
# train: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\train\552f8cd7-1776914759571.jpg: corrupt JPEG restored and saved
# train: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\train\5b650f91-1776914759270.jpg: corrupt JPEG restored and saved
# train: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\train\6653c33f-1776914759709.jpg: corrupt JPEG restored and saved
# train: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\train\6b53c4a4-1776914759270.jpg: corrupt JPEG restored and saved
# train: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\train\8816fc08-1776914759531.jpg: corrupt JPEG restored and saved
# train: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\train\a6339bc1-1776914759408.jpg: corrupt JPEG restored and saved
# train: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\train\b5d364cd-1776914759552.jpg: corrupt JPEG restored and saved
# train: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\train\b7f64362-1776914759584.jpg: corrupt JPEG restored and saved
# train: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\train\bc3afb5b-1776914759692.jpg: corrupt JPEG restored and saved
# train: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\train\bf6494c7-1776914759471.jpg: corrupt JPEG restored and saved
# train: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\train\c92a24d1-1776914759623.jpg: corrupt JPEG restored and saved
# train: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\train\c9ccf848-1776914759206.jpg: corrupt JPEG restored and saved
# train: New cache created: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\labels\train.cache
# val: Fast image access  (ping: 0.10.0 ms, read: 1939.1533.8 MB/s, size: 2625.5 KB)
# val: Scanning C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\labels\val... 49 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 49/49 333.8it/s 0.1s
# val: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\val\c352152a-1776914759362.jpg: corrupt JPEG restored and saved
# val: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\val\d21237ee-1776914759294.jpg: corrupt JPEG restored and saved
# val: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\val\d21363cb-1776914759147.jpg: corrupt JPEG restored and saved
# val: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\val\d7230880-1776914759127.jpg: corrupt JPEG restored and saved
# val: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\val\d8ab919e-1776914759510.jpg: corrupt JPEG restored and saved
# val: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\images\val\db6f6fdd-1776914759623.jpg: corrupt JPEG restored and saved
# val: New cache created: C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\datasets\labels\val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\runs\detect\yolov8n_bunga-kamboja-2\labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\runs\detect\yolov8n_bunga-kamboja-2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100         0G      1.308     0.8493      1.275         57        640: 100% ━━━━━━━━━━━━ 12/12 3.4s/it 41.2s3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.7s<12.4s
#                    all         49        194       0.79      0.679      0.739      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100         0G      1.246      0.828       1.24         52        640: 100% ━━━━━━━━━━━━ 12/12 3.1s/it 37.1s3.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.6s/it 5.1s<11.7s
#                    all         49        194      0.836      0.696      0.769      0.326
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100         0G      1.323     0.8698      1.245         81        640: 100% ━━━━━━━━━━━━ 12/12 2.8s/it 34.1s2.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1s/it 4.2s9.3s
#                    all         49        194       0.72      0.652      0.687      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100         0G      1.299     0.9005      1.257         63        640: 100% ━━━━━━━━━━━━ 12/12 3.1s/it 37.4s3.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.6s/it 5.2s<11.5s
#                    all         49        194      0.659      0.623      0.591      0.251
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100         0G      1.322     0.9098      1.256         65        640: 100% ━━━━━━━━━━━━ 12/12 2.9s/it 34.7s2.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.5s/it 4.9s<10.9s
#                    all         49        194      0.672      0.669      0.636      0.272
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100         0G      1.327      0.882      1.237        171        640: 100% ━━━━━━━━━━━━ 12/12 2.9s/it 35.1s3.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.5s/it 5.0s<11.1s
#                    all         49        194        0.7      0.699      0.673      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100         0G      1.345     0.9322      1.278         82        640: 100% ━━━━━━━━━━━━ 12/12 2.8s/it 33.5s2.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.5s/it 4.9s<10.9s
#                    all         49        194      0.693       0.65      0.663      0.295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100         0G      1.327      0.929      1.292         87        640: 100% ━━━━━━━━━━━━ 12/12 2.7s/it 32.9s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.5s/it 4.9s<11.1s
#                    all         49        194      0.751      0.656      0.693      0.273
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100         0G      1.428     0.9509      1.337         90        640: 100% ━━━━━━━━━━━━ 12/12 2.8s/it 33.4s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.7s/it 5.4s<11.9s
#                    all         49        194      0.831      0.615      0.739      0.286
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100         0G      1.378      0.974      1.312         62        640: 25% ━━━───────── 3/12 2.6s/it 9.9s<23.7s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 model = YOLO('runs/detect/yolov8n_bunga-kamboja/weights/best.pt')
# ----> 3 results = model.train(
#       4     data='bunga-kamboja.yaml',
#       5     epochs=100,
#       6     imgsz=640,
#       7     batch=16,
#       8     name='yolov8n_bunga-kamboja',
#       9     patience=20,
#      10     augment=True
#      11 )
#      13 print("Training selesai!")
#
# File c:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\yolo-venv\Lib\site-packages\ultralytics\engine\model.py:788, in Model.train(self, trainer, **kwargs)
#     785     self.trainer.model = self.trainer.get_model(weights=self.model, cfg=self.model.yaml)
#     786     self.model = self.trainer.model
# --> 788 self.trainer.train()
#     789 # Update model and cfg after training
#     790 if RANK in {-1, 0}:
#
# File c:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\yolo-venv\Lib\site-packages\ultralytics\engine\trainer.py:246, in BaseTrainer.train(self)
#     243             ddp_cleanup(self, str(file))
#     245 else:
# --> 246     self._do_train()
#
# File c:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\yolo-venv\Lib\site-packages\ultralytics\engine\trainer.py:439, in BaseTrainer._do_train(self)
#     437     loss, self.loss_items = unwrap_model(self.model).loss(batch, preds)
#     438 else:
# --> 439     loss, self.loss_items = self.model(batch)
#     440 self.loss = loss.sum()
#     441 if RANK != -1:
#
# File c:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\yolo-venv\Lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\yolo-venv\Lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File c:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\yolo-venv\Lib\site-packages\ultralytics\nn\tasks.py:141, in BaseModel.forward(self, x, *args, **kwargs)
#     128 """Perform forward pass of the model for either training or inference.
#     129
#     130 If x is a dict, calculates and returns the loss for training. Otherwise, returns predictions for inference.
#    (...)    138     (torch.Tensor): Loss if x is a dict (training), or network predictions (inference).
#     139 """
#     140 if isinstance(x, dict):  # for cases of training and validating while training.
# --> 141     return self.loss(x, *args, **kwargs)
#     142 return self.predict(x, *args, **kwargs)
#
# File c:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\yolo-venv\Lib\site-packages\ultralytics\nn\tasks.py:335, in BaseModel.loss(self, batch, preds)
#     333 if preds is None:
#     334     preds = self.forward(batch["img"])
# --> 335 return self.criterion(preds, batch)
#
# File c:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\yolo-venv\Lib\site-packages\ultralytics\utils\loss.py:471, in v8DetectionLoss.__call__(self, preds, batch)
#     465 def __call__(
#     466     self,
#     467     preds: dict[str, torch.Tensor] | tuple[torch.Tensor, dict[str, torch.Tensor]],
#     468     batch: dict[str, torch.Tensor],
#     469 ) -> tuple[torch.Tensor, torch.Tensor]:
#     470     """Calculate the sum of the loss for box, cls and dfl multiplied by batch size."""
# --> 471     return self.loss(self.parse_output(preds), batch)
#
# File c:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\yolo-venv\Lib\site-packages\ultralytics\utils\loss.py:476, in v8DetectionLoss.loss(self, preds, batch)
#     474 """Calculate detection loss using assigned targets."""
#     475 batch_size = preds["boxes"].shape[0]
# --> 476 loss, loss_detach = self.get_assigned_targets_and_loss(preds, batch)[1:]
#     477 return loss * batch_size, loss_detach
#
# File c:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\yolo-venv\Lib\site-packages\ultralytics\utils\loss.py:438, in v8DetectionLoss.get_assigned_targets_and_loss(self, preds, batch)
#     436 # Bbox loss
#     437 if fg_mask.sum():
# --> 438     loss[0], loss[2] = self.bbox_loss(
#     439         pred_distri,
#     440         pred_bboxes,
#     441         anchor_points,
#     442         target_bboxes / stride_tensor,
#     443         target_scores,
#     444         target_scores_sum,
#     445         fg_mask,
#     446         imgsz,
#     447         stride_tensor,
#     448     )
#     450 loss[0] *= self.hyp.box  # box gain
#     451 loss[1] *= self.hyp.cls  # cls gain
#
# File c:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\yolo-venv\Lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\yolo-venv\Lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File c:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\yolo-venv\Lib\site-packages\ultralytics\utils\loss.py:136, in BboxLoss.forward(self, pred_dist, pred_bboxes, anchor_points, target_bboxes, target_scores, target_scores_sum, fg_mask, imgsz, stride)
#     134 # DFL loss
#     135 if self.dfl_loss:
# --> 136     target_ltrb = bbox2dist(anchor_points, target_bboxes, self.dfl_loss.reg_max - 1)
#     137     loss_dfl = self.dfl_loss(pred_dist[fg_mask].view(-1, self.dfl_loss.reg_max), target_ltrb[fg_mask]) * weight
#     138     loss_dfl = loss_dfl.sum() / target_scores_sum
#
# File c:\Users\Nyoman Yogi\Documents\KULI AH\Semester 4\AI\YOLO\1\yolo-venv\Lib\site-packages\ultralytics\utils\tal.py:431, in bbox2dist(anchor_points, bbox, reg_max)
#     429 """Transform bbox(xyxy) to dist(ltrb)."""
#     430 x1y1, x2y2 = bbox.chunk(2, -1)
# --> 431 dist = torch.cat((anchor_points - x1y1, x2y2 - anchor_points), -1)
#     432 if reg_max is not None:
#     433     dist = dist.clamp_(0, reg_max - 0.01)  # dist (lt, rb)
#
# KeyboardInterrupt:

# %%
model = YOLO('runs/detect/yolov8n_bunga-kamboja/weights/best.pt')
metrics = model.val()

print(f"mAP50: {metrics.box.map50:.2f}")
print(f"mAP50-95: {metrics.box.map:.2f}")
print(f"Precision: {metrics.box.mp:.2f}")
print(f"Recall: {metrics.box.mr:.2f}")

# %%
model = YOLO('runs/detect/yolov8n_bunga-kamboja/weights/best.pt')
result = model('datasets/images/train/0fc975ef-1776914757940.jpg', save=True, conf=0.5)
